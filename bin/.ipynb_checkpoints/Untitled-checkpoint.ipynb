# %%
import sys
import argparse
import re
import pandas as pd
import pysradb

# %%
# def unescaped_str(arg_str):
#     """
#     Borrowed from https://stackoverflow.com/questions/34145686/handling-argparse-escaped-character-as-option
#     """
#     return codecs.decode(str(arg_str), 'unicode-escape')

def parse_args(args):
    parser = argparse.ArgumentParser(
        description='Create the input section for distiller\'s project.yml from GEO/ENA/SRA accessions.',
        formatter_class=argparse.ArgumentDefaultsHelpFormatter)
    parser.add_argument(
        'accessions', 
        metavar='N', 
        type=str, 
        nargs='+',
        help='GEO/SRA/ENA accession with a Hi-C project.')
    parser.add_argument(
        '--title_sub', 
        nargs=2, 
        action='append',
#         type=unescaped_str,
        default = [
            ('\s', '_'),
            ('[^\w_.-]', '') # the first character cannot be a hyphen!!
        ],
        help='A list of regular expression substitutions to clean up the experiment titles. '
        'Each substitution must be provided using a separate flag --title_sub followed by '
        'a pair of regular expressions pat repl, separated by a space, '
        'where pat is the matching pattern and repl is the replacement string. '
        'Internally, these expressions are then provided to pandas.Series.str.replace() or re.sub(). '
        'The default substitutions replace spaces with underscores and remove characters not matching '
        'A–Z a–z 0–9 ._- (a.k.a. the POSIX portable file name character set).'
    )
    parser.add_argument(
        '--group_sub', 
        nargs=2, 
        action='append',
#         type=unescaped_str,
        default = [
            ('[_-](R|rep)[\d+]$', '')
        ],
        help='A list of regular expression substitutions to convert experiment titles into groups. '
        'The usage is same as above. The default substitution matches patterns like _R1/_R2/_rep1/-R1/R1 '
        'at the ends of the title.'
    )
    
    parser.print_help()

    return parser.parse_args(args)

def to_downloadable(queries):
    out_queries = []
    for q in queries:
        if q.startswith('GSE'):
            out_queries += list(
                pysradb.SRAweb()
                .gse_to_srp(q)
                .study_accession
            )
        else: 
            out_queries.append(q)
    return out_queries

TAB_CHAR = '    '

# %%
#args = parse_args(sys.argv[1:])
#queries = ['SRP098789']

args = parse_args(['GSE110061'])
display(args)
# Out:
# usage: ipykernel_launcher.py [-h] [--title_sub TITLE_SUB TITLE_SUB]
#                              [--group_sub GROUP_SUB GROUP_SUB]
#                              N [N ...]
#
# Create a table of fastq inputs (for distiller's project.yml) from GEO/ENA/SRA
# accessions.
#
# positional arguments:
#   N                     GEO/SRA/ENA accession with a Hi-C project.
#
# optional arguments:
#   -h, --help            show this help message and exit
#   --title_sub TITLE_SUB TITLE_SUB
#                         A list of regular expression substitutions to clean up
#                         the experiment titles. Each substitution must be
#                         provided using a separate flag --title_sub followed by
#                         a pair of regular expressions pat repl, separated by a
#                         space, where pat is the matching pattern and repl is
#                         the replacement string. Internally, these expressions
#                         are then provided to pandas.Series.str.replace() or
#                         re.sub(). The default substitutions replace spaces
#                         with underscores and remove characters not matching
#                         A–Z a–z 0–9 ._- (a.k.a. the POSIX portable file name
#                         character set). (default: [('\\s', '_'), ('[^\\w_.-]',
#                         '')])
#   --group_sub GROUP_SUB GROUP_SUB
#                         A list of regular expression substitutions to convert
#                         experiment titles into groups. The usage is same as
#                         above. The default substitution matches patterns like
#                         _R1/_R2/_rep1/-R1/R1 at the ends of the title.
#                         (default: [('[_-](R|rep)[\\d+]$', '')])
# Namespace(accessions=['GSE110061'], group_sub=[('[_-](R|rep)[\\d+]$', '')], title_sub=[('\\s', '_'), ('[^\\w_.-]', '')])

# %%
db = pysradb.SRAweb()

queries = to_downloadable(args.accessions)
 
srr_table = pd.concat([    
    db.sra_metadata(q)
    for q in queries
])

srr_table = srr_table[['experiment_title', 'run_accession']]

srr_table['experiment_title'] = (
    srr_table['experiment_title']
    .str.split(';')
    .str.get(0)
    .str.split(':')
    .str.get(1)
    .str.strip()
)

# %%
for re_sub in args.title_sub:
    srr_table['experiment_title'] = (
            srr_table.experiment_title
            .str.replace(re_sub[0], re_sub[1], regex=True)
        )

srr_table=srr_table.sort_values(['experiment_title','run_accession'])
# Out:
# ('\\s', '_')
# ('[^\\w_.-]', '')

# %%
srr_table['lane'] = (
    'lane'
    + (srr_table.groupby('experiment_title').cumcount()+1)
        .astype('str')
)

# %%
group = srr_table.experiment_title
for sub in group_subs:
    group = group.str.replace(sub[0], sub[1])
srr_table['group'] = group

# %%
# Keeping this code in case YAML structures will become useful:

# out_raw_reads_paths = {}
# for title, grouped in srr_table.groupby('experiment_title'):
#     out_raw_reads_paths[title] = {
#         row.lane:f'- sra:{row.run_accession}'
#         for _,row in grouped.iterrows()
#     }

# out_library_groups = {}
# for group, grouped in srr_table.groupby('group'):
#     experiment_titles = list(grouped.experiment_title.unique())
#     if len(experiment_titles) > 1:
#         out_library_groups[group] = experiment_titles


out_raw_reads_paths = [f'{TAB_CHAR}raw_reads_paths:']
for title, grouped in srr_table.groupby('experiment_title'):
    out_raw_reads_paths.append(f'{TAB_CHAR}{TAB_CHAR}{title}:')
    for _, row in grouped.iterrows():
        out_raw_reads_paths.append(f'{TAB_CHAR}{TAB_CHAR}{TAB_CHAR}{row.lane}:')
        out_raw_reads_paths.append(f'{TAB_CHAR}{TAB_CHAR}{TAB_CHAR}{TAB_CHAR}- sra:{row.run_accession}')

out_library_groups = [f'{TAB_CHAR}library_groups:']
for group, grouped in srr_table.groupby('group'):
    experiment_titles = grouped.experiment_title.unique()
    if len(experiment_titles) > 1:
        out_library_groups.append(f'{TAB_CHAR}{TAB_CHAR}{group}:')
        out_library_groups += [f'{TAB_CHAR}{TAB_CHAR}{TAB_CHAR}- {title}' 
                               for title in experiment_titles]

out = '\n'.join(['input:']+out_raw_reads_paths+out_library_groups)

# %%
print(out)
# Out:
# input:
#     raw_reads_paths:
#         BL-CAP-C_F123_CTCF-AID_KO-POLII_G5_rep1:
#             lane1:
#                 - sra:SRR12053682
#             lane2:
#                 - sra:SRR12053683
#             lane3:
#                 - sra:SRR12053684
#         BL-CAP-C_F123_CTCF-AID_KO-POLII_G5_rep2:
#             lane1:
#                 - sra:SRR12053685
#         BL-CAP-C_F123_CTCF-AID_KO_G5_rep1:
#             lane1:
#                 - sra:SRR12053678
#             lane2:
#                 - sra:SRR12053679
#             lane3:
#                 - sra:SRR12053680
#         BL-CAP-C_F123_CTCF-AID_KO_G5_rep2:
#             lane1:
#                 - sra:SRR12053681
#         BL-CAP-C_F123_CTCF-AID_POLII_G5_rep1:
#             lane1:
#                 - sra:SRR12053686
#             lane2:
#                 - sra:SRR12053687
#             lane3:
#                 - sra:SRR12053688
#         BL-CAP-C_F123_CTCF-AID_POLII_G5_rep2:
#             lane1:
#                 - sra:SRR12053689
#         BL-CAP-C_F123_CTCF-AID_WT_G5_rep1:
#             lane1:
#                 - sra:SRR12053674
#             lane2:
#                 - sra:SRR12053675
#             lane3:
#                 - sra:SRR12053676
#         BL-CAP-C_F123_CTCF-AID_WT_G5_rep2:
#             lane1:
#                 - sra:SRR12053677
#         BL-CAP-C_F123_G3_rep1:
#             lane1:
#                 - sra:SRR12053668
#         BL-CAP-C_F123_G3_rep2:
#             lane1:
#                 - sra:SRR12053669
#         BL-CAP-C_F123_G5_rep1:
#             lane1:
#                 - sra:SRR12053670
#         BL-CAP-C_F123_G5_rep2:
#             lane1:
#                 - sra:SRR12053671
#         BL-CAP-C_F123_G7_rep1:
#             lane1:
#                 - sra:SRR12053672
#         BL-CAP-C_F123_G7_rep2:
#             lane1:
#                 - sra:SRR12053673
#         BL-CAP-C_F123_Native_G5_rep1:
#             lane1:
#                 - sra:SRR12053695
#             lane2:
#                 - sra:SRR12053696
#             lane3:
#                 - sra:SRR12053697
#         BL-CAP-C_F123_Native_G7_rep1:
#             lane1:
#                 - sra:SRR12053698
#             lane2:
#                 - sra:SRR12053699
#             lane3:
#                 - sra:SRR12053700
#         BL-CAP-C_F123_Native_G9_rep1:
#             lane1:
#                 - sra:SRR12053701
#             lane2:
#                 - sra:SRR12053702
#             lane3:
#                 - sra:SRR12053703
#         BL-CAP-C_F123_Triptolide:
#             lane1:
#                 - sra:SRR12053705
#         BL-CAP-C_HCT116_Induction_rep1:
#             lane1:
#                 - sra:SRR12053693
#         BL-CAP-C_HCT116_WT_rep1:
#             lane1:
#                 - sra:SRR12053690
#             lane2:
#                 - sra:SRR12053691
#         BL-CAP-C_HepG2_G3_rep1:
#             lane1:
#                 - sra:SRR12053656
#         BL-CAP-C_HepG2_G3_rep2:
#             lane1:
#                 - sra:SRR12053657
#         BL-CAP-C_HepG2_G5_rep1:
#             lane1:
#                 - sra:SRR12053658
#         BL-CAP-C_HepG2_G5_rep2:
#             lane1:
#                 - sra:SRR12053659
#         BL-CAP-C_HepG2_G7_rep1:
#             lane1:
#                 - sra:SRR12053660
#         BL-CAP-C_HepG2_G7_rep2:
#             lane1:
#                 - sra:SRR12053661
#         BL-CAP-C_S2_G3_rep1:
#             lane1:
#                 - sra:SRR12053662
#             lane2:
#                 - sra:SRR12053663
#         BL-CAP-C_S2_G5_rep1:
#             lane1:
#                 - sra:SRR12053664
#             lane2:
#                 - sra:SRR12053665
#         BL-CAP-C_S2_G7_rep1:
#             lane1:
#                 - sra:SRR12053666
#             lane2:
#                 - sra:SRR12053667
#         ChIP-seq_BL-CAP-C_CTCF-AID_WT_Rad21:
#             lane1:
#                 - sra:SRR12053727
#         ChIP-seq_BL-CAP-C_F123_CTCF-AID_KO-POLII_Ctcf:
#             lane1:
#                 - sra:SRR12053712
#         ChIP-seq_BL-CAP-C_F123_CTCF-AID_KO-POLII_Pol2-S2P:
#             lane1:
#                 - sra:SRR12053713
#         ChIP-seq_BL-CAP-C_F123_CTCF-AID_KO-POLII_Pol2-S5P:
#             lane1:
#                 - sra:SRR12053714
#         ChIP-seq_BL-CAP-C_F123_CTCF-AID_KO-POLII_Rad21:
#             lane1:
#                 - sra:SRR12053715
#         ChIP-seq_BL-CAP-C_F123_CTCF-AID_KO_Ctcf:
#             lane1:
#                 - sra:SRR12053716
#         ChIP-seq_BL-CAP-C_F123_CTCF-AID_KO_Pol2-S2P:
#             lane1:
#                 - sra:SRR12053717
#         ChIP-seq_BL-CAP-C_F123_CTCF-AID_KO_Pol2-S5P:
#             lane1:
#                 - sra:SRR12053718
#         ChIP-seq_BL-CAP-C_F123_CTCF-AID_KO_Rad21:
#             lane1:
#                 - sra:SRR12053719
#         ChIP-seq_BL-CAP-C_F123_CTCF-AID_POLII_Ctcf:
#             lane1:
#                 - sra:SRR12053720
#         ChIP-seq_BL-CAP-C_F123_CTCF-AID_POLII_Pol2-S2P:
#             lane1:
#                 - sra:SRR12053721
#         ChIP-seq_BL-CAP-C_F123_CTCF-AID_POLII_Pol2-S5P:
#             lane1:
#                 - sra:SRR12053722
#         ChIP-seq_BL-CAP-C_F123_CTCF-AID_POLII_Rad21:
#             lane1:
#                 - sra:SRR12053723
#         ChIP-seq_BL-CAP-C_F123_CTCF-AID_WT_Ctcf:
#             lane1:
#                 - sra:SRR12053724
#         ChIP-seq_BL-CAP-C_F123_CTCF-AID_WT_Pol2-S2P:
#             lane1:
#                 - sra:SRR12053725
#         ChIP-seq_BL-CAP-C_F123_CTCF-AID_WT_Pol2-S5P:
#             lane1:
#                 - sra:SRR12053726
#         ChIP-seq_BL-CAP-C_HCT116_Induction_CTCF:
#             lane1:
#                 - sra:SRR12053728
#         ChIP-seq_BL-CAP-C_HCT116_Induction_H3K4me3:
#             lane1:
#                 - sra:SRR12053729
#         ChIP-seq_BL-CAP-C_HCT116_Induction_Pol2-S5P:
#             lane1:
#                 - sra:SRR12053730
#         ChIP-seq_BL-CAP-C_HCT116_Induction_SMC3:
#             lane1:
#                 - sra:SRR12053731
#         ChIP-seq_BL-CAP-C_HCT116_WT_CTCF:
#             lane1:
#                 - sra:SRR12053732
#         ChIP-seq_BL-CAP-C_HCT116_WT_H3K4me3:
#             lane1:
#                 - sra:SRR12053733
#         ChIP-seq_BL-CAP-C_HCT116_WT_Pol2-S5P:
#             lane1:
#                 - sra:SRR12053734
#         ChIP-seq_BL-CAP-C_HCT116_WT_SMC3:
#             lane1:
#                 - sra:SRR12053735
#         DNaseHiC_F123_rep1:
#             lane1:
#                 - sra:SRR12053706
#             lane2:
#                 - sra:SRR12053707
#             lane3:
#                 - sra:SRR12053708
#         DNaseHiC_F123_rep2:
#             lane1:
#                 - sra:SRR12053709
#             lane2:
#                 - sra:SRR12053710
#             lane3:
#                 - sra:SRR12053711
#         F123_CAP-C_G3_rep1:
#             lane1:
#                 - sra:SRR6667402
#             lane2:
#                 - sra:SRR6667403
#             lane3:
#                 - sra:SRR6667404
#         F123_CAP-C_G3_rep2:
#             lane1:
#                 - sra:SRR6667405
#             lane2:
#                 - sra:SRR6667406
#             lane3:
#                 - sra:SRR6667407
#         F123_CAP-C_G5_rep1:
#             lane1:
#                 - sra:SRR6667408
#             lane2:
#                 - sra:SRR6667409
#             lane3:
#                 - sra:SRR6667410
#         F123_CAP-C_G5_rep2:
#             lane1:
#                 - sra:SRR6667411
#             lane2:
#                 - sra:SRR6667412
#             lane3:
#                 - sra:SRR6667413
#         F123_CAP-C_G7_rep1:
#             lane1:
#                 - sra:SRR6667414
#             lane2:
#                 - sra:SRR6667415
#             lane3:
#                 - sra:SRR6667416
#         F123_CAP-C_G7_rep2:
#             lane1:
#                 - sra:SRR6667417
#             lane2:
#                 - sra:SRR6667418
#             lane3:
#                 - sra:SRR6667419
#         F123_CAP-C_No_UV:
#             lane1:
#                 - sra:SRR6667423
#         F123_CAP-C_No_dendrimer:
#             lane1:
#                 - sra:SRR6667422
#         F123_CAP-C_No_proteinase_K:
#             lane1:
#                 - sra:SRR6667424
#         F123_Top2b_ChIPSeq:
#             lane1:
#                 - sra:SRR6667433
#         F123_in-situ_Hi-C_rep1:
#             lane1:
#                 - sra:SRR6667420
#         F123_in-situ_Hi-C_rep2:
#             lane1:
#                 - sra:SRR6667421
#         F123_input_DNA:
#             lane1:
#                 - sra:SRR6667434
#         PLAC-seq_F123_KO-POLII_POL2-S5P:
#             lane1:
#                 - sra:SRR12053738
#         PLAC-seq_F123_KO_POL2-S5P:
#             lane1:
#                 - sra:SRR12053737
#         PLAC-seq_F123_POLII-hexanediol_POL2-S5P:
#             lane1:
#                 - sra:SRR12053740
#         PLAC-seq_F123_POLII_POL2-S5P:
#             lane1:
#                 - sra:SRR12053739
#         PLAC-seq_F123_WT_POL2-S5P:
#             lane1:
#                 - sra:SRR12053736
#     library_groups:
#         BL-CAP-C_F123_CTCF-AID_KO-POLII_G5:
#             - BL-CAP-C_F123_CTCF-AID_KO-POLII_G5_rep1
#             - BL-CAP-C_F123_CTCF-AID_KO-POLII_G5_rep2
#         BL-CAP-C_F123_CTCF-AID_KO_G5:
#             - BL-CAP-C_F123_CTCF-AID_KO_G5_rep1
#             - BL-CAP-C_F123_CTCF-AID_KO_G5_rep2
#         BL-CAP-C_F123_CTCF-AID_POLII_G5:
#             - BL-CAP-C_F123_CTCF-AID_POLII_G5_rep1
#             - BL-CAP-C_F123_CTCF-AID_POLII_G5_rep2
#         BL-CAP-C_F123_CTCF-AID_WT_G5:
#             - BL-CAP-C_F123_CTCF-AID_WT_G5_rep1
#             - BL-CAP-C_F123_CTCF-AID_WT_G5_rep2
#         BL-CAP-C_F123_G3:
#             - BL-CAP-C_F123_G3_rep1
#             - BL-CAP-C_F123_G3_rep2
#         BL-CAP-C_F123_G5:
#             - BL-CAP-C_F123_G5_rep1
#             - BL-CAP-C_F123_G5_rep2
#         BL-CAP-C_F123_G7:
#             - BL-CAP-C_F123_G7_rep1
#             - BL-CAP-C_F123_G7_rep2
#         BL-CAP-C_HepG2_G3:
#             - BL-CAP-C_HepG2_G3_rep1
#             - BL-CAP-C_HepG2_G3_rep2
#         BL-CAP-C_HepG2_G5:
#             - BL-CAP-C_HepG2_G5_rep1
#             - BL-CAP-C_HepG2_G5_rep2
#         BL-CAP-C_HepG2_G7:
#             - BL-CAP-C_HepG2_G7_rep1
#             - BL-CAP-C_HepG2_G7_rep2
#         DNaseHiC_F123:
#             - DNaseHiC_F123_rep1
#             - DNaseHiC_F123_rep2
#         F123_CAP-C_G3:
#             - F123_CAP-C_G3_rep1
#             - F123_CAP-C_G3_rep2
#         F123_CAP-C_G5:
#             - F123_CAP-C_G5_rep1
#             - F123_CAP-C_G5_rep2
#         F123_CAP-C_G7:
#             - F123_CAP-C_G7_rep1
#             - F123_CAP-C_G7_rep2
#         F123_in-situ_Hi-C:
#             - F123_in-situ_Hi-C_rep1
#             - F123_in-situ_Hi-C_rep2
